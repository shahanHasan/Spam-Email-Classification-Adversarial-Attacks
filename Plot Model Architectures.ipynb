# %%
from keras.models import load_model
from keras.utils.vis_utils import plot_model, model_to_dot

# %%
ANN_word_embedding = load_model("Model/ANN.h5")
ANN_glove_1 = load_model("Model/ANN_glove_1.h5")
ANN_glove_2 = load_model("Model/ANN_glove_2.h5")

RNN_word_embedding = load_model("Model/RNN.h5")
RNN_glove_1 = load_model("Model/RNN_glove_1.h5")
RNN_glove_2 = load_model("Model/RNN_glove_2.h5")

CNN_word_embedding = load_model("Model/CNN.h5")
CNN_glove_1 = load_model("Model/CNN_glove_1.h5")
CNN_glove_2 = load_model("Model/CNN_glove_2.h5")

# %%
plot_model(
    ANN_word_embedding,
    # to_file="drive/MyDrive/SPAM classification deep learning/Visuals/ann_glove_1.jpeg",
    to_file=f"Architecture_Diagrams/ANN_word_Embedding.jpeg",
    show_shapes=True,
    show_dtype=True,
    show_layer_names=True,
    rankdir="LR",
    expand_nested=False,
    dpi=96,
    layer_range=None,
)

# %%
plot_model(
    ANN_glove_1,
    # to_file="drive/MyDrive/SPAM classification deep learning/Visuals/ann_glove_1.jpeg",
    to_file=f"Architecture_Diagrams/ANN_glove_1.jpeg",
    show_shapes=True,
    show_dtype=True,
    show_layer_names=True,
    rankdir="LR",
    expand_nested=False,
    dpi=96,
    layer_range=None,
)

# %%
plot_model(
    ANN_glove_2,
    # to_file="drive/MyDrive/SPAM classification deep learning/Visuals/ann_glove_1.jpeg",
    to_file=f"Architecture_Diagrams/ANN_glove_2.jpeg",
    show_shapes=True,
    show_dtype=True,
    show_layer_names=True,
    rankdir="LR",
    expand_nested=False,
    dpi=96,
    layer_range=None,
)

# %%
plot_model(
    RNN_word_embedding,
    # to_file="drive/MyDrive/SPAM classification deep learning/Visuals/ann_glove_1.jpeg",
    to_file=f"Architecture_Diagrams/RNN_word_Embedding.jpeg",
    show_shapes=True,
    show_dtype=True,
    show_layer_names=True,
    rankdir="LR",
    expand_nested=False,
    dpi=96,
    layer_range=None,
)

# %%
plot_model(
    RNN_glove_1,
    # to_file="drive/MyDrive/SPAM classification deep learning/Visuals/ann_glove_1.jpeg",
    to_file=f"Architecture_Diagrams/RNN_glove_1.jpeg",
    show_shapes=True,
    show_dtype=True,
    show_layer_names=True,
    rankdir="LR",
    expand_nested=False,
    dpi=96,
    layer_range=None,
)

# %%
plot_model(
    RNN_glove_2,
    # to_file="drive/MyDrive/SPAM classification deep learning/Visuals/ann_glove_1.jpeg",
    to_file=f"Architecture_Diagrams/RNN_glove_2.jpeg",
    show_shapes=True,
    show_dtype=True,
    show_layer_names=True,
    rankdir="LR",
    expand_nested=False,
    dpi=96,
    layer_range=None,
)

# %%
plot_model(
    CNN_word_embedding,
    # to_file="drive/MyDrive/SPAM classification deep learning/Visuals/ann_glove_1.jpeg",
    to_file=f"Architecture_Diagrams/CNN_word_Embedding.jpeg",
    show_shapes=True,
    show_dtype=True,
    show_layer_names=True,
    rankdir="LR",
    expand_nested=False,
    dpi=96,
    layer_range=None,
)

# %%
plot_model(
    CNN_glove_1,
    # to_file="drive/MyDrive/SPAM classification deep learning/Visuals/ann_glove_1.jpeg",
    to_file=f"Architecture_Diagrams/CNN_glove_1.jpeg",
    show_shapes=True,
    show_dtype=True,
    show_layer_names=True,
    rankdir="LR",
    expand_nested=False,
    dpi=96,
    layer_range=None,
)

# %%
plot_model(
    CNN_glove_2,
    # to_file="drive/MyDrive/SPAM classification deep learning/Visuals/ann_glove_1.jpeg",
    to_file=f"Architecture_Diagrams/CNN_glove_2.jpeg",
    show_shapes=True,
    show_dtype=True,
    show_layer_names=True,
    rankdir="LR",
    expand_nested=False,
    dpi=96,
    layer_range=None,
)
